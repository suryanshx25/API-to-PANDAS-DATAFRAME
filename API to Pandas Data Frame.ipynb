# %%
 # 8265bd1679663a7ea12ac168da84d2e8

# %%
 # https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1').json()

# %%
response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 124.137,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 18388},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %%
response['total_results']
# Out:
# 11353

# %%
response['total_pages']
# Out:
# 568

# %%
response['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 124.137,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 18388},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
for i in response['results']:
    print(i['title'])
# Out:
# The Godfather
# The Shawshank Redemption
# The Godfather Part II
# Schindler's List
# Dilwale Dulhania Le Jayenge
# Spirited Away
# 12 Angry Men
# Your Name.
# Parasite
# The Dark Knight
# The Green Mile
# Pulp Fiction
# Forrest Gump
# The Lord of the Rings: The Return of the King
# Spider-Man: Across the Spider-Verse
# The Good, the Bad and the Ugly
# GoodFellas
# Cinema Paradiso
# Cuando Sea Joven
# Life Is Beautiful

# %%
for i in response['results']:
    print(i['title'],i['vote_average'])
# Out:
# The Godfather 8.7
# The Shawshank Redemption 8.7
# The Godfather Part II 8.6
# Schindler's List 8.6
# Dilwale Dulhania Le Jayenge 8.6
# Spirited Away 8.5
# 12 Angry Men 8.5
# Your Name. 8.5
# Parasite 8.5
# The Dark Knight 8.5
# The Green Mile 8.5
# Pulp Fiction 8.5
# Forrest Gump 8.5
# The Lord of the Rings: The Return of the King 8.5
# Spider-Man: Across the Spider-Verse 8.5
# The Good, the Bad and the Ugly 8.5
# GoodFellas 8.5
# Cinema Paradiso 8.5
# Cuando Sea Joven 8.5
# Life Is Beautiful 8.5

# %%
popularity = []
vote_count = []
title = []
original_language = []
overview = []
vote_average = []
release_date = []

for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    title.append(i['title'])
    original_language.append(i['original_language'])
    overview.append(i['overview'])
    vote_average.append(i['vote_average'])
    release_date.append(i['release_date'])
    
    
    d = {'title' : title, 'overview' : overview, 'release_date' : release_date, 'popularity' : popularity, 'vote_count' : vote_count, 'original_language' : original_language, 'vote_average' : vote_average}
    df = pd.DataFrame(d)

# %%
df
# Out:
#                                             title  \
# 0                                   The Godfather
# 1                        The Shawshank Redemption
# 2                           The Godfather Part II
# 3                                Schindler's List
# 4                     Dilwale Dulhania Le Jayenge
# 5                                   Spirited Away
# 6                                    12 Angry Men
# 7                                      Your Name.
# 8                                        Parasite
# 9                                 The Dark Knight
# 10                                 The Green Mile
# 11                                   Pulp Fiction
# 12                                   Forrest Gump
# 13  The Lord of the Rings: The Return of the King
# 14            Spider-Man: Across the Spider-Verse
# 15                 The Good, the Bad and the Ugly
# 16                                     GoodFellas
# 17                                Cinema Paradiso
# ...

# %%
final = pd.DataFrame()

for j in range(1,10):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(j)).json()
    popularity = []
    vote_count = []
    title = []
    original_language = []
    overview = []
    vote_average = []
    release_date = []

    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        title.append(i['title'])
        original_language.append(i['original_language'])
        overview.append(i['overview'])
        vote_average.append(i['vote_average'])
        release_date.append(i['release_date'])


        d = {'title' : title, 'overview' : overview, 'release_date' : release_date, 'popularity' : popularity, 'vote_count' : vote_count, 'original_language' : original_language, 'vote_average' : vote_average}
        df = pd.DataFrame(d)
        
        final = final.append(df, ignore_index=True)
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_6272\1754294372.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)

# %%
final.shape
# Out:
# (1890, 7)

# %%
final.to_csv('movies.csv')

# %%
df= pd.read_csv('movies.csv')

# %%
final
# Out:
#                                                   title  \
# 0                                         The Godfather
# 1                                         The Godfather
# 2                              The Shawshank Redemption
# 3                                         The Godfather
# 4                              The Shawshank Redemption
# ...                                                 ...
# 1885                                         Metropolis
# 1886                                         My Friends
# 1887                                               Soul
# 1888  Abraham Lincoln Vampire Hunter: The Great Cala...
# 1889                         Michael Jackson's Thriller
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# ...

# %%
final.to_csv('movies.csv')
